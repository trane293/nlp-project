# %%
eng_set = open('../data/hansards.en', 'rb')
fr_set = open('../data/hansards.fr', 'rb')

# %%
for line_en, line_fr in zip(eng_set, fr_set):
    print('en: {}\nfr: {}\n\n'.format(line_en, line_fr))
# Out:
# en: 2 .
#
# fr: 2 .
#
#
#
# en: 2 .
#
# fr: 2 .
#
#
#
# en: oh , oh !
#
# fr: oh , oh !
#
#
#
# en: oh , oh !
#
# fr: oh , oh !
#
#
#
# en: oh , oh !
#
# fr: oh , oh !
#
#
#
# en: let us remember , Mr. Speaker , that these segments of our society form the backbone of our economy .
#
# fr: souvenons - nous , monsieur le Orateur , que ce sont ces secteurs de notre société qui servent de épine dorsale à notre économie .
#
#
#
# en: hear , hear !
#
# fr: bravo !
#
#
#
# en: hear , hear !
#
# fr: bravo !
#
#
#
# en: Mr. Speaker , my question is directed to the Minister of Transport .
#
# fr: monsieur le Orateur , ma question se adresse à le ministre chargé de les transports .
#
#
#
# en: both have many years experience in the manufacture and distribution of forest products .
#
# fr: tous deux possèdent de nombreuses années de expérience dans la fabrication et la distribution de les produits forestiers .
#
#
#
# en: 1 .
#
# fr: 1 .
#
#
#
# ...

# %%
fr_set.
