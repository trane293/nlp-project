# %% [markdown]
# ## chartEntry Datastructure

# %%
from __future__ import print_function
import pandas as pd
from pandas.io.parsers import read_csv
import heapq as heapq
import numpy as np

class chartEntry:
    """
    This class implements the data structure "Entry" described in the baseline
    algorithm. The pseduocode for the description is:
    
    Entry(word, start-position, end-position, log-probability, back-pointer)
    
    We define the __lt__ and __eq__ operators to allow comparisons betwen two entries when 
    trying to push them into the heap. This operator respects the sort_acc_to variable and 
    provides boolean value accordingly. 

    It supports operations based on two ideas - i) sorting by start_pos
                                                ii) sorting by log_prob. 
        
    IMPORTANT NOTE: For Comparison, two objects can be compared based upon their start-pos 
    or log-prob (depending upon the initial setting of sort_acc_to when defining the objects) 
    using the normal comparison operators like < or >. HOWEVER, equals comparison SHOULD ONLY 
    BE MADE USING isEquals() function, and NOT ==. 
    
    
    EXAMPLE USAGE: 
        p = chartEntry('Anmol', 0, 4, 0.2, -1, sort_acc_to='start_pos')
        print(p)
        p.get_item('log_prob')
        e1 = chartEntry('Anmol', 0, 4, 0.2, -1)
        e2 = chartEntry("Shreeashish", 5, 10, 0.5, 0)
        e3 = chartEntry('Amir Ali', 11, 16, 0.4, 1)
        p1 = chartEntry('Anmol', 0, 4, 0.2, -1, sort_acc_to='start_pos')
        p2 = chartEntry('Anmol', 0, 4, 0.2, -1, sort_acc_to='start_pos')
        p1.isEqual(p2) [TRUE]
        
    This work is a part of the Assignment 1 of CMPT 825 Natural Language Processing
    taught by Prof. Anoop Sarkar. 
    
    AUTHOR: Anmol Sharma, GroupNLP
    INSTITUTION: Simon Fraser University
    """
    
    def __init__(self, word, start_pos, end_pos, log_prob, back_ptr, sort_acc_to='start_pos'):
        self.instance = {}
        self.instance['word'] = word
        self.instance['start_pos'] = start_pos
        self.instance['end_pos'] = end_pos
        self.instance['log_prob'] = log_prob
        self.instance['back_ptr'] = back_ptr
        self.__sort_type = sort_acc_to
        
    def __repr__(self):
        return "chartEntry({}, {}, {}, {}, {})".format(self.instance['word'], self.instance['start_pos'], \
                                              self.instance['end_pos'], self.instance['log_prob'],\
                                              self.instance['back_ptr'])
    
    def __lt__(self, other_obj):
        if self.__sort_type == 'start_pos':
            return (self.instance['start_pos'] < other_obj.instance['start_pos'])
        else:
            return (self.instance['log_prob'] < other_obj.instance['log_prob'])
    
    def __gt__(self, other_obj):
        if self.__sort_type == 'start_pos':
            return (self.instance['start_pos'] > other_obj.instance['start_pos'])
        else:
            return (self.instance['log_prob'] > other_obj.instance['log_prob'])
    
    def __eq__(self, other_obj):
        if self.__sort_type == 'start_pos':
            return (self.instance['start_pos'] == other_obj.instance['start_pos'])
        else:
            return (self.instance['log_prob'] == other_obj.instance['log_prob'])
    
    def isEqual(self, other_obj):
        for k in self.instance:
            if self.instance[k] == other_obj.instance[k]:
                continue
            else:
                return False
        return True
    
    def get_item(self, key):
        return self.instance[key] if key in self.instance else "Undefined Key"

# %% [markdown]
# ## Start building the heap

# %%
class Heap:
    """
    A class wrapper for heapq datastructure implementation of python. Python's default heapq 
    implementation requires a list as initialized heap, however it doesn't provide
    any safeguards against the fact that the underlying list may be changed by some function. 
    
    To provide safeguard mechanism, this class wraps the push and pop functions of heapq. 
    
    EXAMPLE USAGE:
        sort_acc_to='log_prob'
        p = chartEntry('Anmol', 0, 4, 0.2, -1, sort_acc_to)
        print(p)
        p.get_item('log_prob')
        e1 = chartEntry('Anmol', 0, 4, 0.6, -1, sort_acc_to)
        e2 = chartEntry("Shreeashish", 5, 10, 0.5, 0, sort_acc_to)
        e3 = chartEntry('Amir Ali', 11, 16, 0.1, 1, sort_acc_to)
        heap1 = Heap()
        heap1.push(e1)
        heap1.push(e2)
        heap1.push(e3)
        heap1.pop()
        
    This work is a part of the Assignment 1 of CMPT 825 Natural Language Processing
    taught by Prof. Anoop Sarkar. 
    
    AUTHOR: Anmol Sharma, GroupNLP
    INSTITUTION: Simon Fraser University
    """
    
    def __init__(self, ls=None):
        self.__heap = ls if ls else []
        heapq.heapify(self.__heap)
        
    def push(self, item):
        heapq.heappush(self.__heap, item)
    
    def pop(self):
        return heapq.heappop(self.__heap)
    
    def __len__(self):
        return len(self.__heap)
    
    def __repr__(self):
        return "{}".format(self.__heap)

# %% [markdown]
# ## Let's start implemeting the algorithm

# %%
class Pdist(dict):
    "A probability distribution estimated from counts in datafile."

    def __init__(self, filename, sep='\t', N=None, missingfn=None):
        self.maxlen = 0 
        for line in file(filename):
            (key, freq) = line.split(sep)
            try:
                utf8key = unicode(key, 'utf-8')
            except:
                raise ValueError("Unexpected error %s" % (sys.exc_info()[0]))
            self[utf8key] = self.get(utf8key, 0) + int(freq)
            self.maxlen = max(len(utf8key), self.maxlen)
        self.N = float(N or sum(self.itervalues()))
        self.missingfn = missingfn or (lambda k, N: 1./N)

    def __call__(self, key):
        if key in self: return float(self[key])/float(self.N)
        #else: return self.missingfn(key, self.N)
        elif len(key) == 1: return self.missingfn(key, self.N)
        else: return None

# %%
# build the probability distribution over the unigram frequencies in count_1w
Pw  = Pdist('../data/count_1w.txt')

# %% [markdown]
# ## Heap initialization

# %%
"""
NOTE: Correct conversion of str to unicode is highly important in this example, so need to be
careful whenever we use anything related to the words themselves. Also, remember when you "print"
a unicode character, it will print the actual character (the chinese letter), but if you view
it in a list, it will show up as a unicode string. 
"""
def initHeap(input_filename='../data/input', counts_filename='../data/count_1w.txt', \
             sort_acc_to='log_prob'):
    
    # initialize heap and open input and counts file
    heap = Heap()
    input_file = open(input_filename, 'rb')
    counts_file = open(counts_filename, 'rb')

    # read the first line from the input file and convert it into a list of characters
    input_line = input_file.readline()
    input_chars = [i for i in unicode(input_line, 'utf-8')]

    # iterate through the counts file to find all instances which match the first character at position 0
    for word_line in counts_file:
        key, freq = word_line.split('\t')
        word_chars = [i for i in unicode(key, 'utf-8')]

        
        # compare the first character of the word from counts file to the first character of input line
         if word_chars[0] == input_chars[0]:
            print('Input: {}'.format("".join(input_chars).encode('utf-8')))
            print('Matched: {}\n'.format("".join(word_chars).encode('utf-8')))

            # create a new entry. Note the .encode('utf-8) which is very important here. We use log_2 
            # probability here. 
            entry = chartEntry("".join(word_chars).encode('utf-8'), start_pos=0, end_pos=len(word_chars),\
                                                log_prob=np.log2(Pw("".join(word_chars))), back_ptr=None,\
                                                sort_acc_to=sort_acc_to)
            print(entry, '\n')

            # push the new entry to the heap
            heap.push(entry)
            
            
    return heap

# %%
heap = initHeap(input_filename='../data/input', counts_filename='../data/count_1w.txt', \
             sort_acc_to='log_prob')
# Out:
# Input: 法正研究从波黑撤军计划
#
# Matched: 县长
#
# chartEntry(县长, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 微型
#
# chartEntry(微型, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 漳州
#
# chartEntry(漳州, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 游乐园
#
# chartEntry(游乐园, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 谈
#
# chartEntry(谈, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 第二
#
# chartEntry(第二, 0, 2, -11.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 还要
#
# chartEntry(还要, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 副市长
#
# chartEntry(副市长, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 第五
#
# chartEntry(第五, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 居于
#
# chartEntry(居于, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 为主
#
# chartEntry(为主, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 吸纳
#
# chartEntry(吸纳, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 韩正
#
# chartEntry(韩正, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 花蕾
#
# chartEntry(花蕾, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 缔造
#
# chartEntry(缔造, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 铺平
#
# chartEntry(铺平, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 委员
#
# chartEntry(委员, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 钦州港
#
# chartEntry(钦州港, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 事务部
#
# chartEntry(事务部, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 日本人
#
# chartEntry(日本人, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 河
#
# chartEntry(河, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 赣江
#
# chartEntry(赣江, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 出来
#
# chartEntry(出来, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 立方米
#
# chartEntry(立方米, 0, 3, -12.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五百四十六亿
#
# chartEntry(五百四十六亿, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 线
#
# chartEntry(线, 0, 1, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 看作
#
# chartEntry(看作, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 事务
#
# chartEntry(事务, 0, 2, -12.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 伊
#
# chartEntry(伊, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 瓦轴
#
# chartEntry(瓦轴, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 学科
#
# chartEntry(学科, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 黑豹
#
# chartEntry(黑豹, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 通往
#
# chartEntry(通往, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 牌
#
# chartEntry(牌, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 制药
#
# chartEntry(制药, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 困境
#
# chartEntry(困境, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十亿
#
# chartEntry(二十亿, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 凝聚
#
# chartEntry(凝聚, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 发射场
#
# chartEntry(发射场, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 难以
#
# chartEntry(难以, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 巴布亚新几内亚
#
# chartEntry(巴布亚新几内亚, 0, 7, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 升起
#
# chartEntry(升起, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 区位
#
# chartEntry(区位, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 知
#
# chartEntry(知, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 除
#
# chartEntry(除, 0, 1, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 世纪
#
# chartEntry(世纪, 0, 2, -11.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 承包商
#
# chartEntry(承包商, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 起诉
#
# chartEntry(起诉, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 西藏
#
# chartEntry(西藏, 0, 2, -12.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 东欧
#
# chartEntry(东欧, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 盈利
#
# chartEntry(盈利, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 理事国
#
# chartEntry(理事国, 0, 3, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十五
#
# chartEntry(二十五, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五百亿
#
# chartEntry(五百亿, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 税法
#
# chartEntry(税法, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 杨伟光
#
# chartEntry(杨伟光, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 红新月会
#
# chartEntry(红新月会, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 餐饮业
#
# chartEntry(餐饮业, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 第七
#
# chartEntry(第七, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 第一
#
# chartEntry(第一, 0, 2, -10.0365976229, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 园
#
# chartEntry(园, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 油气田
#
# chartEntry(油气田, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 第三
#
# chartEntry(第三, 0, 2, -11.984130203, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 官员
#
# chartEntry(官员, 0, 2, -11.984130203, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 应
#
# chartEntry(应, 0, 1, -11.2889847845, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 审核
#
# chartEntry(审核, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 招商会
#
# chartEntry(招商会, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地方性
#
# chartEntry(地方性, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 张明全
#
# chartEntry(张明全, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 公路
#
# chartEntry(公路, 0, 2, -11.4222513154, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 为了
#
# chartEntry(为了, 0, 2, -12.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: Ｒ·Ｈ·梅西
#
# chartEntry(Ｒ·Ｈ·梅西, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 朱国贤
#
# chartEntry(朱国贤, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 卫生部
#
# chartEntry(卫生部, 0, 3, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 留驻
#
# chartEntry(留驻, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 敦促
#
# chartEntry(敦促, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 冶
#
# chartEntry(冶, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 规范化
#
# chartEntry(规范化, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 发售
#
# chartEntry(发售, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五百万
#
# chartEntry(五百万, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 明确
#
# chartEntry(明确, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 吉尔吉斯
#
# chartEntry(吉尔吉斯, 0, 4, -12.4695570301, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 班汉
#
# chartEntry(班汉, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 制成品
#
# chartEntry(制成品, 0, 3, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 第九
#
# chartEntry(第九, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 帐目
#
# chartEntry(帐目, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 细纱机
#
# chartEntry(细纱机, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 史记
#
# chartEntry(史记, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十三
#
# chartEntry(二十三, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开工
#
# chartEntry(开工, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 新闻
#
# chartEntry(新闻, 0, 2, -11.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十万
#
# chartEntry(二十万, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十一
#
# chartEntry(二十一, 0, 3, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十七
#
# chartEntry(二十七, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 市政局
#
# chartEntry(市政局, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 产品
#
# chartEntry(产品, 0, 2, -9.39916770224, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 纵横
#
# chartEntry(纵横, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 须
#
# chartEntry(须, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 收回
#
# chartEntry(收回, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 巨人
#
# chartEntry(巨人, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 供应量
#
# chartEntry(供应量, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 目前
#
# chartEntry(目前, 0, 2, -9.00140819439, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 加以
#
# chartEntry(加以, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 兼顾
#
# chartEntry(兼顾, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 上
#
# chartEntry(上, 0, 1, -8.31035843528, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 掀开
#
# chartEntry(掀开, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 后
#
# chartEntry(后, 0, 1, -9.98413020296, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 蒙
#
# chartEntry(蒙, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 年均
#
# chartEntry(年均, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 机制
#
# chartEntry(机制, 0, 2, -12.1285201123, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 职能
#
# chartEntry(职能, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 谢云挺
#
# chartEntry(谢云挺, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 份额
#
# chartEntry(份额, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 中转
#
# chartEntry(中转, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 周根良
#
# chartEntry(周根良, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 古脊椎所
#
# chartEntry(古脊椎所, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 伴
#
# chartEntry(伴, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 正当
#
# chartEntry(正当, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 县支行
#
# chartEntry(县支行, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 离
#
# chartEntry(离, 0, 1, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 事变
#
# chartEntry(事变, 0, 2, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 日子
#
# chartEntry(日子, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 以色列人
#
# chartEntry(以色列人, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 有力
#
# chartEntry(有力, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七月
#
# chartEntry(七月, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 修复
#
# chartEntry(修复, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五千一百亿
#
# chartEntry(五千一百亿, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 岗位
#
# chartEntry(岗位, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 占据
#
# chartEntry(占据, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 看中
#
# chartEntry(看中, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 铝业
#
# chartEntry(铝业, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 审计法
#
# chartEntry(审计法, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 互补
#
# chartEntry(互补, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开展
#
# chartEntry(开展, 0, 2, -11.8528856697, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 小儿麻痹
#
# chartEntry(小儿麻痹, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 消费类
#
# chartEntry(消费类, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 正式
#
# chartEntry(正式, 0, 2, -11.732591436, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 非分之想
#
# chartEntry(非分之想, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 削弱
#
# chartEntry(削弱, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 走私
#
# chartEntry(走私, 0, 2, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 计委
#
# chartEntry(计委, 0, 2, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 号
#
# chartEntry(号, 0, 1, -11.4222513154, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 为何
#
# chartEntry(为何, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 令狐道成
#
# chartEntry(令狐道成, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 称道
#
# chartEntry(称道, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 三十四
#
# chartEntry(三十四, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之三十三点八
#
# chartEntry(百分之三十三点八, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 快于
#
# chartEntry(快于, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 版图
#
# chartEntry(版图, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 贡觉扎朗
#
# chartEntry(贡觉扎朗, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 修
#
# chartEntry(修, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 对外部
#
# chartEntry(对外部, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 袭来
#
# chartEntry(袭来, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 人事
#
# chartEntry(人事, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 火炬形
#
# chartEntry(火炬形, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 名牌
#
# chartEntry(名牌, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七十七点八一万
#
# chartEntry(七十七点八一万, 0, 7, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 意见
#
# chartEntry(意见, 0, 2, -12.6760079076, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 三十三点二四亿
#
# chartEntry(三十三点二四亿, 0, 7, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 胶结
#
# chartEntry(胶结, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十余
#
# chartEntry(二十余, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 出版商
#
# chartEntry(出版商, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 郑耀棠
#
# chartEntry(郑耀棠, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 其次
#
# chartEntry(其次, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 居住
#
# chartEntry(居住, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 反
#
# chartEntry(反, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 比利时
#
# chartEntry(比利时, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 彩电
#
# chartEntry(彩电, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 坏
#
# chartEntry(坏, 0, 1, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四十三亿
#
# chartEntry(四十三亿, 0, 4, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 头等
#
# chartEntry(头等, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 洪锦
#
# chartEntry(洪锦, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 风头
#
# chartEntry(风头, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 几
#
# chartEntry(几, 0, 1, -11.0188956211, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 错误
#
# chartEntry(错误, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 干扰素
#
# chartEntry(干扰素, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 加上
#
# chartEntry(加上, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 巨
#
# chartEntry(巨, 0, 1, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 检讨
#
# chartEntry(检讨, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 治肝
#
# chartEntry(治肝, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 主导型
#
# chartEntry(主导型, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 有利
#
# chartEntry(有利, 0, 2, -12.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 房舍
#
# chartEntry(房舍, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 正常
#
# chartEntry(正常, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 缅甸
#
# chartEntry(缅甸, 0, 2, -12.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 缓和
#
# chartEntry(缓和, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地表
#
# chartEntry(地表, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 内河
#
# chartEntry(内河, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百三十二
#
# chartEntry(一百三十二, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 那天
#
# chartEntry(那天, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 农发
#
# chartEntry(农发, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 轻纺
#
# chartEntry(轻纺, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 强大
#
# chartEntry(强大, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 较
#
# chartEntry(较, 0, 1, -10.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 归来
#
# chartEntry(归来, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 游泳
#
# chartEntry(游泳, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 谋求
#
# chartEntry(谋求, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开张
#
# chartEntry(开张, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百四十一
#
# chartEntry(一百四十一, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百四十万
#
# chartEntry(一百四十万, 0, 5, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 国产化
#
# chartEntry(国产化, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 谢金虎
#
# chartEntry(谢金虎, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 欧亚
#
# chartEntry(欧亚, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百三十亿
#
# chartEntry(一百三十亿, 0, 5, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 新股
#
# chartEntry(新股, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 物种
#
# chartEntry(物种, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一样
#
# chartEntry(一样, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 三峡
#
# chartEntry(三峡, 0, 2, -11.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 执委会
#
# chartEntry(执委会, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 应邀
#
# chartEntry(应邀, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 驻美
#
# chartEntry(驻美, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 三百一十五
#
# chartEntry(三百一十五, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十二
#
# chartEntry(二十二, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 摄
#
# chartEntry(摄, 0, 1, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 耸立
#
# chartEntry(耸立, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 改造
#
# chartEntry(改造, 0, 2, -11.984130203, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 农历
#
# chartEntry(农历, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 率领
#
# chartEntry(率领, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 灵敏
#
# chartEntry(灵敏, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 朱砂
#
# chartEntry(朱砂, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 司令
#
# chartEntry(司令, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 基地
#
# chartEntry(基地, 0, 2, -11.0910454069, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 活
#
# chartEntry(活, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 机关
#
# chartEntry(机关, 0, 2, -12.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 切片
#
# chartEntry(切片, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 探将
#
# chartEntry(探将, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 学
#
# chartEntry(学, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 三十亿零八千多万
#
# chartEntry(三十亿零八千多万, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 鲜花
#
# chartEntry(鲜花, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 短评
#
# chartEntry(短评, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 到任
#
# chartEntry(到任, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 出口额
#
# chartEntry(出口额, 0, 3, -11.8528856697, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 顾耀铭
#
# chartEntry(顾耀铭, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之二十三点二
#
# chartEntry(百分之二十三点二, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 高考
#
# chartEntry(高考, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 互访
#
# chartEntry(互访, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百三十七
#
# chartEntry(一百三十七, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 劝业
#
# chartEntry(劝业, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之三十六点九
#
# chartEntry(百分之三十六点九, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 倍数
#
# chartEntry(倍数, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 台资
#
# chartEntry(台资, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百四十亿
#
# chartEntry(一百四十亿, 0, 5, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 定值
#
# chartEntry(定值, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ６７８
#
# chartEntry(６７８, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 有关
#
# chartEntry(有关, 0, 2, -9.95018287104, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 托管
#
# chartEntry(托管, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 录相机
#
# chartEntry(录相机, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 普通话
#
# chartEntry(普通话, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 侦察
#
# chartEntry(侦察, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 前途
#
# chartEntry(前途, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 高耸
#
# chartEntry(高耸, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 突出
#
# chartEntry(突出, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 做到
#
# chartEntry(做到, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七百八十一点三亿
#
# chartEntry(七百八十一点三亿, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之三十六点三
#
# chartEntry(百分之三十六点三, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 非排他性
#
# chartEntry(非排他性, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之三十六点七
#
# chartEntry(百分之三十六点七, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 成都
#
# chartEntry(成都, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百三十九
#
# chartEntry(一百三十九, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 全部
#
# chartEntry(全部, 0, 2, -12.1285201123, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 秒
#
# chartEntry(秒, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 连
#
# chartEntry(连, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一亿多
#
# chartEntry(一亿多, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 弱点
#
# chartEntry(弱点, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 羽绒
#
# chartEntry(羽绒, 0, 2, -12.6760079076, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之二十二点六二
#
# chartEntry(百分之二十二点六二, 0, 9, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 连续
#
# chartEntry(连续, 0, 2, -11.8528856697, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 相
#
# chartEntry(相, 0, 1, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 驻
#
# chartEntry(驻, 0, 1, -11.3320535064, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 好
#
# chartEntry(好, 0, 1, -11.1669942601, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 曙光
#
# chartEntry(曙光, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 中资
#
# chartEntry(中资, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 产地
#
# chartEntry(产地, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 魅力
#
# chartEntry(魅力, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 或
#
# chartEntry(或, 0, 1, -10.8218587741, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 在一起
#
# chartEntry(在一起, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 十二万多
#
# chartEntry(十二万多, 0, 4, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 拐杖
#
# chartEntry(拐杖, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 明白卡
#
# chartEntry(明白卡, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 舞台
#
# chartEntry(舞台, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 实习生
#
# chartEntry(实习生, 0, 3, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 澳
#
# chartEntry(澳, 0, 1, -12.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 双方
#
# chartEntry(双方, 0, 2, -10.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 镜湖
#
# chartEntry(镜湖, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 试验区
#
# chartEntry(试验区, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 随后
#
# chartEntry(随后, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 喜庆
#
# chartEntry(喜庆, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 十二亿
#
# chartEntry(十二亿, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 维和
#
# chartEntry(维和, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开幕
#
# chartEntry(开幕, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 解除
#
# chartEntry(解除, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 去
#
# chartEntry(去, 0, 1, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 阻挠
#
# chartEntry(阻挠, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 太原
#
# chartEntry(太原, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二千三百八十一点五亿
#
# chartEntry(二千三百八十一点五亿, 0, 10, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 省份
#
# chartEntry(省份, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 资质证
#
# chartEntry(资质证, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 赞同
#
# chartEntry(赞同, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 厂长
#
# chartEntry(厂长, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 太阳能
#
# chartEntry(太阳能, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 着陆
#
# chartEntry(着陆, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 撰写
#
# chartEntry(撰写, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 基因
#
# chartEntry(基因, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 亲戚
#
# chartEntry(亲戚, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 行驶
#
# chartEntry(行驶, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ３
#
# chartEntry(３, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 控股
#
# chartEntry(控股, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 王炜中
#
# chartEntry(王炜中, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 负
#
# chartEntry(负, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 山
#
# chartEntry(山, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 有偿
#
# chartEntry(有偿, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 意识
#
# chartEntry(意识, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百零二
#
# chartEntry(一百零二, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七日
#
# chartEntry(七日, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 奋斗
#
# chartEntry(奋斗, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 钢丝床
#
# chartEntry(钢丝床, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 所长
#
# chartEntry(所长, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 军工
#
# chartEntry(军工, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 低廉
#
# chartEntry(低廉, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 专业性
#
# chartEntry(专业性, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 导弹
#
# chartEntry(导弹, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 当
#
# chartEntry(当, 0, 1, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 招标
#
# chartEntry(招标, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之九点七
#
# chartEntry(百分之九点七, 0, 6, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 十二万
#
# chartEntry(十二万, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 筹组
#
# chartEntry(筹组, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 苗木
#
# chartEntry(苗木, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 爱护
#
# chartEntry(爱护, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 卡拉季奇
#
# chartEntry(卡拉季奇, 0, 4, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 王战
#
# chartEntry(王战, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 郑重
#
# chartEntry(郑重, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 媒介
#
# chartEntry(媒介, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 零散
#
# chartEntry(零散, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 产值
#
# chartEntry(产值, 0, 2, -10.6215601236, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 蘑菇云
#
# chartEntry(蘑菇云, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 着重
#
# chartEntry(着重, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 收到
#
# chartEntry(收到, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 机场
#
# chartEntry(机场, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ‘
#
# chartEntry(‘, 0, 1, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 龙永图
#
# chartEntry(龙永图, 0, 3, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 座
#
# chartEntry(座, 0, 1, -12.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 烈士
#
# chartEntry(烈士, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 晶体
#
# chartEntry(晶体, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 定名
#
# chartEntry(定名, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 长命锁
#
# chartEntry(长命锁, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 年初
#
# chartEntry(年初, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 发酵
#
# chartEntry(发酵, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 案
#
# chartEntry(案, 0, 1, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 秘密
#
# chartEntry(秘密, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 徐兴堂
#
# chartEntry(徐兴堂, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四十八点九亿
#
# chartEntry(四十八点九亿, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五千三百二十
#
# chartEntry(五千三百二十, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七成
#
# chartEntry(七成, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 贬值
#
# chartEntry(贬值, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 择业
#
# chartEntry(择业, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 炒作
#
# chartEntry(炒作, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 确认
#
# chartEntry(确认, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 精品
#
# chartEntry(精品, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 清莱
#
# chartEntry(清莱, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 观点
#
# chartEntry(观点, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ━
#
# chartEntry(━, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 勇气
#
# chartEntry(勇气, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 院校
#
# chartEntry(院校, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 蒙得维的亚
#
# chartEntry(蒙得维的亚, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 学校
#
# chartEntry(学校, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 淄博市
#
# chartEntry(淄博市, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 微生物
#
# chartEntry(微生物, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 十三亿五千七百多万
#
# chartEntry(十三亿五千七百多万, 0, 9, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 天
# chartEntry(天, 0, 1, -11.4222513154, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 级别
#
# chartEntry(级别, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 谭刚伦
#
# chartEntry(谭刚伦, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 比什凯克
#
# chartEntry(比什凯克, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 纺织品
#
# chartEntry(纺织品, 0, 3, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地质
#
# chartEntry(地质, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 侵占
#
# chartEntry(侵占, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 采用
#
# chartEntry(采用, 0, 2, -12.6760079076, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之六十一点八三
#
# chartEntry(百分之六十一点八三, 0, 9, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 择人
#
# chartEntry(择人, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 麦克拉伦
#
# chartEntry(麦克拉伦, 0, 4, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 超越
#
# chartEntry(超越, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开始
#
# chartEntry(开始, 0, 2, -10.6760079076, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 不用
#
# chartEntry(不用, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 上海港
#
# chartEntry(上海港, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 宝日希勒
#
# chartEntry(宝日希勒, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 十佳
#
# chartEntry(十佳, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 倪四义
#
# chartEntry(倪四义, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之七十三点九
#
# chartEntry(百分之七十三点九, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 擅自
#
# chartEntry(擅自, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 泰
#
# chartEntry(泰, 0, 1, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 动脉
#
# chartEntry(动脉, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四千四百余
#
# chartEntry(四千四百余, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一九五０年
#
# chartEntry(一九五０年, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 改革
#
# chartEntry(改革, 0, 2, -9.9670566896, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 背景
#
# chartEntry(背景, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 毛朝敬
#
# chartEntry(毛朝敬, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １１月
#
# chartEntry(１１月, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 副国防部长
#
# chartEntry(副国防部长, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 同样
#
# chartEntry(同样, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １５０
#
# chartEntry(１５０, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 英萨利
#
# chartEntry(英萨利, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七十六点六亿
#
# chartEntry(七十六点六亿, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 能源
#
# chartEntry(能源, 0, 2, -11.8528856697, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 弘扬
#
# chartEntry(弘扬, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １５６
#
# chartEntry(１５６, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 种植
#
# chartEntry(种植, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 占有
#
# chartEntry(占有, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 儿科
#
# chartEntry(儿科, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 节水
#
# chartEntry(节水, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １５％
#
# chartEntry(１５％, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 支出
#
# chartEntry(支出, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百零九点九亿
#
# chartEntry(一百零九点九亿, 0, 7, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之五十八
#
# chartEntry(百分之五十八, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 机器
#
# chartEntry(机器, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之五十六
#
# chartEntry(百分之五十六, 0, 6, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 过
#
# chartEntry(过, 0, 1, -12.2889847845, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 机械化
#
# chartEntry(机械化, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 冰层
#
# chartEntry(冰层, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ８５％
#
# chartEntry(８５％, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 答
#
# chartEntry(答, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 全面
#
# chartEntry(全面, 0, 2, -11.5184666306, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 势力
#
# chartEntry(势力, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 设卡
#
# chartEntry(设卡, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 氨伦
#
# chartEntry(氨伦, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 枯树
#
# chartEntry(枯树, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 船舶
#
# chartEntry(船舶, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 择优
#
# chartEntry(择优, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一九九七年
#
# chartEntry(一九九七年, 0, 5, -10.8845945294, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 天体
#
# chartEntry(天体, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 土石
#
# chartEntry(土石, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 金硕仁
#
# chartEntry(金硕仁, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 信息网
#
# chartEntry(信息网, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二百四十万
#
# chartEntry(二百四十万, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 于青
#
# chartEntry(于青, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 枢纽港
#
# chartEntry(枢纽港, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 逆差
#
# chartEntry(逆差, 0, 2, -12.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 代表
#
# chartEntry(代表, 0, 2, -10.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 消化
#
# chartEntry(消化, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 翅膀
#
# chartEntry(翅膀, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二百一十多万
#
# chartEntry(二百一十多万, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 禁运
#
# chartEntry(禁运, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之八十二
#
# chartEntry(百分之八十二, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 取得
#
# chartEntry(取得, 0, 2, -10.5184666306, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 力争
#
# chartEntry(力争, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 灭杀
#
# chartEntry(灭杀, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 永垂不朽
#
# chartEntry(永垂不朽, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 配送
#
# chartEntry(配送, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 研讨会
#
# chartEntry(研讨会, 0, 3, -12.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 沈阳
#
# chartEntry(沈阳, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五笔
#
# chartEntry(五笔, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 增至
#
# chartEntry(增至, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 航道
#
# chartEntry(航道, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 约见
#
# chartEntry(约见, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 办事处
#
# chartEntry(办事处, 0, 3, -12.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 变样
#
# chartEntry(变样, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 使用权
#
# chartEntry(使用权, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之六十五
#
# chartEntry(百分之六十五, 0, 6, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 中草药
#
# chartEntry(中草药, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一站式
#
# chartEntry(一站式, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 标准箱
#
# chartEntry(标准箱, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 降
#
# chartEntry(降, 0, 1, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 产出
#
# chartEntry(产出, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 机械厂
#
# chartEntry(机械厂, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一九八六
#
# chartEntry(一九八六, 0, 4, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 安玻
#
# chartEntry(安玻, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 十五日
#
# chartEntry(十五日, 0, 3, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 古
#
# chartEntry(古, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 零部件
#
# chartEntry(零部件, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 水平
#
# chartEntry(水平, 0, 2, -10.3991677022, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 药
#
# chartEntry(药, 0, 1, -12.4695570301, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 填平
#
# chartEntry(填平, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二万余
#
# chartEntry(二万余, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 保管
#
# chartEntry(保管, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开花吐艳
#
# chartEntry(开花吐艳, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 收取
#
# chartEntry(收取, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十二点八五亿
#
# chartEntry(二十二点八五亿, 0, 7, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 罹难者
#
# chartEntry(罹难者, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 极
#
# chartEntry(极, 0, 1, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之十七点九五
#
# chartEntry(百分之十七点九五, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 主任
#
# chartEntry(主任, 0, 2, -12.1285201123, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 中行
#
# chartEntry(中行, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 死难
#
# chartEntry(死难, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 霍姆斯
#
# chartEntry(霍姆斯, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 智能
#
# chartEntry(智能, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 儿童
#
# chartEntry(儿童, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 免去
#
# chartEntry(免去, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 芦湖
#
# chartEntry(芦湖, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 巴尔干
#
# chartEntry(巴尔干, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 千条瀑
#
# chartEntry(千条瀑, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 北京
#
# chartEntry(北京, 0, 2, -9.46955703013, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 丰
#
# chartEntry(丰, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 企划厅
#
# chartEntry(企划厅, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 文章
#
# chartEntry(文章, 0, 2, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 荣恒
#
# chartEntry(荣恒, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 同步
#
# chartEntry(同步, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 增资额
#
# chartEntry(增资额, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 主人
#
# chartEntry(主人, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 五点六九亿
#
# chartEntry(五点六九亿, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 毁坏
#
# chartEntry(毁坏, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 征税
#
# chartEntry(征税, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 北仑
#
# chartEntry(北仑, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 卖给
#
# chartEntry(卖给, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 狗不理
#
# chartEntry(狗不理, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 失明
#
# chartEntry(失明, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 深深
#
# chartEntry(深深, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 招聘点
#
# chartEntry(招聘点, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 开学
#
# chartEntry(开学, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 支助
#
# chartEntry(支助, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 采矿
#
# chartEntry(采矿, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 作好
#
# chartEntry(作好, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 燃烧
#
# chartEntry(燃烧, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 据
#
# chartEntry(据, 0, 1, -9.01012541149, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 新德里
#
# chartEntry(新德里, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 自流
#
# chartEntry(自流, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 签
#
# chartEntry(签, 0, 1, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 赔偿
#
# chartEntry(赔偿, 0, 2, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 辆
#
# chartEntry(辆, 0, 1, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 超过
#
# chartEntry(超过, 0, 2, -10.7040222838, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 和
#
# chartEntry(和, 0, 1, -6.52313807034, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 宁盐
#
# chartEntry(宁盐, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ＡＢＳ
#
# chartEntry(ＡＢＳ, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 沉重
#
# chartEntry(沉重, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 岸线
#
# chartEntry(岸线, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 动荡
#
# chartEntry(动荡, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 国家党
#
# chartEntry(国家党, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 长期
#
# chartEntry(长期, 0, 2, -12.1285201123, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 遍布
#
# chartEntry(遍布, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 松江
#
# chartEntry(松江, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 法律
#
# chartEntry(法律, 0, 2, -12.4695570301, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 服务部
#
# chartEntry(服务部, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 异常
#
# chartEntry(异常, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 稳健
#
# chartEntry(稳健, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 宾
#
# chartEntry(宾, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 打击
#
# chartEntry(打击, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 大楼
#
# chartEntry(大楼, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四十多亿
#
# chartEntry(四十多亿, 0, 4, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 丰硕
#
# chartEntry(丰硕, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一开始
#
# chartEntry(一开始, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 左翼
#
# chartEntry(左翼, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 镍
#
# chartEntry(镍, 0, 1, -12.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ＰＯＳ
#
# chartEntry(ＰＯＳ, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 偏
#
# chartEntry(偏, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 常驻
#
# chartEntry(常驻, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 涂盖
#
# chartEntry(涂盖, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 纽带
#
# chartEntry(纽带, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 任
#
# chartEntry(任, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 昆山
#
# chartEntry(昆山, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 公认
#
# chartEntry(公认, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之二十六点五
#
# chartEntry(百分之二十六点五, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 爱尔兰
#
# chartEntry(爱尔兰, 0, 3, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 分项
#
# chartEntry(分项, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 同比
#
# chartEntry(同比, 0, 2, -12.4695570301, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 顿
#
# chartEntry(顿, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 大连市
#
# chartEntry(大连市, 0, 3, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百七十八亿
#
# chartEntry(一百七十八亿, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 赣南
#
# chartEntry(赣南, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百三十九点六亿
#
# chartEntry(一百三十九点六亿, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 锌
#
# chartEntry(锌, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 递交
#
# chartEntry(递交, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 摊位
#
# chartEntry(摊位, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 验证
#
# chartEntry(验证, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 正好
#
# chartEntry(正好, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 安玻人
#
# chartEntry(安玻人, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 供
#
# chartEntry(供, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 东汉
#
# chartEntry(东汉, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 解释
#
# chartEntry(解释, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 总设计师
#
# chartEntry(总设计师, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 无序
#
# chartEntry(无序, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 消费税
#
# chartEntry(消费税, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ９０年代
#
# chartEntry(９０年代, 0, 4, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 答词
#
# chartEntry(答词, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一派
#
# chartEntry(一派, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 富余
#
# chartEntry(富余, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 彩玻
#
# chartEntry(彩玻, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一流
#
# chartEntry(一流, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 收入
#
# chartEntry(收入, 0, 2, -11.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 博览会
#
# chartEntry(博览会, 0, 3, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 正大
#
# chartEntry(正大, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 成长
#
# chartEntry(成长, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 罐
#
# chartEntry(罐, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地被
#
# chartEntry(地被, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 强烈
#
# chartEntry(强烈, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 收养
#
# chartEntry(收养, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 路子
#
# chartEntry(路子, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 靠
#
# chartEntry(靠, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 誉为
#
# chartEntry(誉为, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 庭审
#
# chartEntry(庭审, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 书法
#
# chartEntry(书法, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 安然
#
# chartEntry(安然, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 控制线
#
# chartEntry(控制线, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 观念
#
# chartEntry(观念, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一九四六年
#
# chartEntry(一九四六年, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 冷战
#
# chartEntry(冷战, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 自治
#
# chartEntry(自治, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 杀手
#
# chartEntry(杀手, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 看
#
# chartEntry(看, 0, 1, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 汇率
#
# chartEntry(汇率, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 涉及
#
# chartEntry(涉及, 0, 2, -12.2889847845, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 法规性
#
# chartEntry(法规性, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 税款
#
# chartEntry(税款, 0, 2, -12.4695570301, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 长春
#
# chartEntry(长春, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 上市
#
# chartEntry(上市, 0, 2, -11.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 主体
#
# chartEntry(主体, 0, 2, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 嫁接
#
# chartEntry(嫁接, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 深水
#
# chartEntry(深水, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 涉台
#
# chartEntry(涉台, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 主持
#
# chartEntry(主持, 0, 2, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 卓越
#
# chartEntry(卓越, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ５００
#
# chartEntry(５００, 0, 3, -15.3764476257, None)
#
# ...
#
# Matched: 创出
#
# chartEntry(创出, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 介绍
#
# chartEntry(介绍, 0, 2, -10.3320535064, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 却
#
# chartEntry(却, 0, 1, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 排位
#
# chartEntry(排位, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七亿多
#
# chartEntry(七亿多, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 制造者
#
# chartEntry(制造者, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 制约
#
# chartEntry(制约, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 迁址
#
# chartEntry(迁址, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 不
#
# chartEntry(不, 0, 1, -9.14762893524, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地球
#
# chartEntry(地球, 0, 2, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地理
#
# chartEntry(地理, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ７
#
# chartEntry(７, 0, 1, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二百三十一点九五亿
#
# chartEntry(二百三十一点九五亿, 0, 9, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之八十九点四
#
# chartEntry(百分之八十九点四, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 共和
#
# chartEntry(共和, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 学者层
#
# chartEntry(学者层, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 内部
#
# chartEntry(内部, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 统筹
#
# chartEntry(统筹, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 走出
#
# chartEntry(走出, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 长鸣
#
# chartEntry(长鸣, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 注意
#
# chartEntry(注意, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 办
#
# chartEntry(办, 0, 1, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 负责
#
# chartEntry(负责, 0, 2, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 俄罗斯
#
# chartEntry(俄罗斯, 0, 3, -10.732591436, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 注塑机
#
# chartEntry(注塑机, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四百三十八点八亿
#
# chartEntry(四百三十八点八亿, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 利国
#
# chartEntry(利国, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 寄
#
# chartEntry(寄, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 交汇处
#
# chartEntry(交汇处, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 味道
#
# chartEntry(味道, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １９９４年
#
# chartEntry(１９９４年, 0, 5, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 糖
#
# chartEntry(糖, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 王永民
#
# chartEntry(王永民, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 资本
#
# chartEntry(资本, 0, 2, -11.732591436, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 某些
#
# chartEntry(某些, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 温州市
#
# chartEntry(温州市, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 女奴
#
# chartEntry(女奴, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 鸭鸭牌
#
# chartEntry(鸭鸭牌, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 七百九十万
#
# chartEntry(七百九十万, 0, 5, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 结局
#
# chartEntry(结局, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １９４１年
#
# chartEntry(１９４１年, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 农业部
#
# chartEntry(农业部, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二十一亿多
#
# chartEntry(二十一亿多, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 事
#
# chartEntry(事, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 创办
#
# chartEntry(创办, 0, 2, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 平方米
#
# chartEntry(平方米, 0, 3, -12.6760079076, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 政治局
#
# chartEntry(政治局, 0, 3, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 发电厂
#
# chartEntry(发电厂, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 试航
#
# chartEntry(试航, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 前沿
#
# chartEntry(前沿, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 总部
#
# chartEntry(总部, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 刘晖
#
# chartEntry(刘晖, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 东南部
#
# chartEntry(东南部, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 从此以后
#
# chartEntry(从此以后, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 塑料
#
# chartEntry(塑料, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 羯鼓
#
# chartEntry(羯鼓, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 全民
#
# chartEntry(全民, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 半数
#
# chartEntry(半数, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 羽毛
#
# chartEntry(羽毛, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 撤回
#
# chartEntry(撤回, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一点九
#
# chartEntry(一点九, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 刘卫东
#
# chartEntry(刘卫东, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 阿齐兹
#
# chartEntry(阿齐兹, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 扩改建
#
# chartEntry(扩改建, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 画家
#
# chartEntry(画家, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 烧碱
#
# chartEntry(烧碱, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 年吞吐量
#
# chartEntry(年吞吐量, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 档次
#
# chartEntry(档次, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 连云港
#
# chartEntry(连云港, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二滩
#
# chartEntry(二滩, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 红十字会
#
# chartEntry(红十字会, 0, 4, -12.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四
#
# chartEntry(四, 0, 1, -11.3320535064, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 餐饮
#
# chartEntry(餐饮, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一点三
#
# chartEntry(一点三, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 珠海港
#
# chartEntry(珠海港, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一点七
#
# chartEntry(一点七, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 希腊
#
# chartEntry(希腊, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 地矿
#
# chartEntry(地矿, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百七十
#
# chartEntry(一百七十, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 散布
#
# chartEntry(散布, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 顺应
#
# chartEntry(顺应, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 玻壳
#
# chartEntry(玻壳, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 劳力
#
# chartEntry(劳力, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 山麓
#
# chartEntry(山麓, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: ３０
#
# chartEntry(３０, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百八十五点六亿
#
# chartEntry(一百八十五点六亿, 0, 8, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 乌鲁木齐市
#
# chartEntry(乌鲁木齐市, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 科威特
#
# chartEntry(科威特, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 植物
#
# chartEntry(植物, 0, 2, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 销售额
#
# chartEntry(销售额, 0, 3, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 颗粒
#
# chartEntry(颗粒, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 轮
#
# chartEntry(轮, 0, 1, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 安装
#
# chartEntry(安装, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 冻结
#
# chartEntry(冻结, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 执法
#
# chartEntry(执法, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 培植
#
# chartEntry(培植, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 黑龙江省
#
# chartEntry(黑龙江省, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 排油烟机
#
# chartEntry(排油烟机, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 友谊
#
# chartEntry(友谊, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 轻舟
#
# chartEntry(轻舟, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 个体
#
# chartEntry(个体, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 来源于
#
# chartEntry(来源于, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 王齐
#
# chartEntry(王齐, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 生物学
#
# chartEntry(生物学, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 市政
#
# chartEntry(市政, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 女子
#
# chartEntry(女子, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 保肝
#
# chartEntry(保肝, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 再生产
#
# chartEntry(再生产, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 村
#
# chartEntry(村, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 油画
#
# chartEntry(油画, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 皖赣
#
# chartEntry(皖赣, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 油田
#
# chartEntry(油田, 0, 2, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 陆斌
#
# chartEntry(陆斌, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 编码法
#
# chartEntry(编码法, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 各自
#
# chartEntry(各自, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 房改办
#
# chartEntry(房改办, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 走势
#
# chartEntry(走势, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 多元化
#
# chartEntry(多元化, 0, 3, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 盛大
#
# chartEntry(盛大, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 四十五点五亿
#
# chartEntry(四十五点五亿, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 漂白
#
# chartEntry(漂白, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 吻合
#
# chartEntry(吻合, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一点五
#
# chartEntry(一点五, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 拉脱维亚
#
# chartEntry(拉脱维亚, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 它
#
# chartEntry(它, 0, 1, -11.1285201123, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 笔挺
#
# chartEntry(笔挺, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 数字
#
# chartEntry(数字, 0, 2, -12.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 渔船
#
# chartEntry(渔船, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 光斑
#
# chartEntry(光斑, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 例
#
# chartEntry(例, 0, 1, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 《
#
# chartEntry(《, 0, 1, -10.0014081944, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 棉纺锭
#
# chartEntry(棉纺锭, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 驯化
#
# chartEntry(驯化, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 阿尔贝托·藤森
#
# chartEntry(阿尔贝托·藤森, 0, 7, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 投票
#
# chartEntry(投票, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 萨达姆
#
# chartEntry(萨达姆, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 承认
#
# chartEntry(承认, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 击中
#
# chartEntry(击中, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 传
#
# chartEntry(传, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 谢
#
# chartEntry(谢, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 私营
#
# chartEntry(私营, 0, 2, -12.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 百分之九十七
#
# chartEntry(百分之九十七, 0, 6, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 苏军
#
# chartEntry(苏军, 0, 2, -14.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 二千四百万
#
# chartEntry(二千四百万, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 在乎
#
# chartEntry(在乎, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 一百六十多亿
#
# chartEntry(一百六十多亿, 0, 6, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 总量
#
# chartEntry(总量, 0, 2, -12.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 位居
#
# chartEntry(位居, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 层
#
# chartEntry(层, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 承诺
#
# chartEntry(承诺, 0, 2, -13.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 个人
#
# chartEntry(个人, 0, 2, -13.2065226243, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 南宁市
#
# chartEntry(南宁市, 0, 3, -12.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 药品
#
# chartEntry(药品, 0, 2, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 熄灭
#
# chartEntry(熄灭, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 方便
#
# chartEntry(方便, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: １９８０年
#
# chartEntry(１９８０年, 0, 5, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 畜
#
# chartEntry(畜, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 债权
#
# chartEntry(债权, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 畜牧
#
# chartEntry(畜牧, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 兴
#
# chartEntry(兴, 0, 1, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 调整期
#
# chartEntry(调整期, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 叶迪生
#
# chartEntry(叶迪生, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 皆
#
# chartEntry(皆, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 科学家
#
# chartEntry(科学家, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 大惑不解
#
# chartEntry(大惑不解, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 杨振亚
#
# chartEntry(杨振亚, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 尽快
#
# chartEntry(尽快, 0, 2, -13.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 宁连
#
# chartEntry(宁连, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 得天独厚
#
# chartEntry(得天独厚, 0, 4, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 规矩
#
# chartEntry(规矩, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 数据库
#
# chartEntry(数据库, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 小组
#
# chartEntry(小组, 0, 2, -12.9170160071, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 接送
#
# chartEntry(接送, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 股份制
#
# chartEntry(股份制, 0, 3, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 与会
#
# chartEntry(与会, 0, 2, -14.0545195309, None)
# Input: 法正研究从波黑撤军计划
#
# Matched: 西宁市
#
# chartEntry(西宁市, 0, 3, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 土质
#
# chartEntry(土质, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 结合部
#
# chartEntry(结合部, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 证实
#
# chartEntry(证实, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 风陵渡
#
# chartEntry(风陵渡, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 洋溢
#
# chartEntry(洋溢, 0, 2, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 硅
#
# chartEntry(硅, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 集
#
# chartEntry(集, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 又
#
# chartEntry(又, 0, 1, -11.0188956211, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 怀念
#
# chartEntry(怀念, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 互相
#
# chartEntry(互相, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 棉纺
#
# chartEntry(棉纺, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 行星
#
# chartEntry(行星, 0, 2, -14.791485125, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 司法
#
# chartEntry(司法, 0, 2, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 取决于
#
# chartEntry(取决于, 0, 3, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 重工业
#
# chartEntry(重工业, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 乡
#
# chartEntry(乡, 0, 1, -13.0545195309, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 宽阔
#
# chartEntry(宽阔, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 波
#
# chartEntry(波, 0, 1, -15.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 检疫
#
# chartEntry(检疫, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 逆差额
#
# chartEntry(逆差额, 0, 3, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 性能
#
# chartEntry(性能, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 火山
#
# chartEntry(火山, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 海
#
# chartEntry(海, 0, 1, -14.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 件
#
# chartEntry(件, 0, 1, -13.5690927037, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 诸
#
# chartEntry(诸, 0, 1, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 馈赠
#
# chartEntry(馈赠, 0, 2, -16.3764476257, None)
#
# Input: 法正研究从波黑撤军计划
#
# Matched: 模拟
#
# chartEntry(模拟, 0, 2, -16.3764476257, None)

# %%
"""
Implimenting baseline algorithem.
Each line of the input file is one sentence. 
We initilize the heap by matching the count_1w and then use DP to find the best matching segmentation.
"""
def initHeap(input_filename='../data/input', counts_filename='../data/count_1w.txt', \
             sort_acc_to='log_prob'):
